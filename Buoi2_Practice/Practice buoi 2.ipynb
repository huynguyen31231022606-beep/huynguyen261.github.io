# %% [markdown]
# # Bài tập luyện tập buổi 2

# %%
#So sánh
# Nhập dữ liệu 
a = float(input("Moi ban nhap so a: ")) 
b = float(input("Moi ban nhap so b: "))
# Xử lý 
laNhoHon = (a < b) 
laNhoHonBang = (a <= b)
laLonHon = (a > b) 
laLonHonBang = (a >= b)
laBang = (a == b)
laKhacNhau = (a != b)
# Xuất dữ liệu 
print("Ket qua so sanh hai so thuc %.2f va %.2f:"%(a, b))
print("%-8.2f < %8.2f: %8s"%(a, b, laNhoHon))
print("%-8.2f <= %8.2f: %8s"%(a, b, laNhoHonBang))
print("%-8.2f > %8.2f: %8s"%(a, b, laLonHon))
print("%-8.2f >= %8.2f: %8s"%(a, b, laLonHonBang))
print("%-8.2f == %8.2f: %8s"%(a, b, laBang))
print("%-8.2f != %8.2f: %8s"%(a, b, laKhacNhau))
# Out:
# Moi ban nhap so a:  2
# Moi ban nhap so b:  3
# Ket qua so sanh hai so thuc 2.00 va 3.00:
# 2.00     <     3.00:     True
# 2.00     <=     3.00:     True
# 2.00     >     3.00:    False
# 2.00     >=     3.00:    False
# 2.00     ==     3.00:    False
# 2.00     !=     3.00:     True

# %%
#Max3Num
# Input a, b, c
a = int(input())
b = int(input())
c = int(input())

# max a, b, c
def max_fn(a, b):
    return a if a > b else b
    pass # max_fn

vmax = max_fn(a, b)
vmax = max_fn(vmax, c)

# output
print("Max(%d, %d, %d) = %d"%(a, b, c, vmax))
# Out:
#  2
#  3
#  4
# Max(2, 3, 4) = 4

# %%
#In ra kết quả mong muôn
print("Hello, World!")
# Out:
# Hello, World!

# %%
#Chiết khấu dòng tiền
pv = 100
r=2
n=5
fv=pv*((1+r/100)**n)
print("Gia tri tuong lai dong tien: ", round(fv,2))
# Out:
# Gia tri tuong lai dong tien:  110.41

# %%
from IPython.display import display

# %%
print("Hello, World")
display("Hello, World!")
# Out:
# Hello, World
# 'Hello, World!'

# %%
# Ghi chu
'''
Ghi chu
'''
print("Comment")
# Out:
# Comment

# %%
#Cấu trúc câu điều kiện
score = 90
if score > 60:
    print("Passed")
else:
    print("Failed")

'''
Câu điều kiện có thể chỉ có if then hoặc if then else hoặc kết hợp nhiều hơn các điều kiện khác
'''
# Out:
# Passed
# '\nCâu điều kiện có thể chỉ có if then hoặc if then else hoặc kết hợp nhiều hơn các điều kiện khác\n'

# %%
# Python variables
x = 2
price = 2.5
word = 'Hello'

word = 'Hello'
word = "Hello"
word = '''Hello'''
print(x, price, word)
print(f'x = {x, type(x)}, price={price, type(price)}, word={word, type(word)}')
# Out:
# 2 2.5 Hello
# x = (2, <class 'int'>), price=(2.5, <class 'float'>), word=('Hello', <class 'str'>)

# %%
y=3
price2=4.5
word2="New price updated"
print(y,price2,word2)
print(f'y={y, type(y)}, price 2={price2, type(price2)}, word2={word2,type(word2)}')
# Out:
# 3 4.5 New price updated
# y=(3, <class 'int'>), price 2=(4.5, <class 'float'>), word2=('New price updated', <class 'str'>)

# %% [markdown]
# ## Kết thúc
