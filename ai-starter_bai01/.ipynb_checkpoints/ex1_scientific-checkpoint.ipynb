# %% [markdown]
# # Exercise 1 - Scientific 1

# %% [markdown]
# ## Nội dung bài
# Hiển thị ngẫu nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1 \right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0, 1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0, 1 \right]$

# %% [markdown]
# ## Bài làm

# %% [markdown]
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hiển thị rich output

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# %time
# generate randomly the center (x,y ) of circle, color, area
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2 # 0 to 15 point radii
# Out:
# CPU times: user 3 μs, sys: 0 ns, total: 3 μs
# Wall time: 5.72 μs

# %%
# Mã kiểm tra dữ liệu
print(f'x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples [{x[0:10]}]')
print(f'y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples [{y[0:10]}]')
print(f'colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples [{colors[0:10]}]')
print(f'area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples [{area[0:10]}]')
# Out:
# x: len=50, [0.00, 0.98]: 10 samples [[0.13471751 0.02937896 0.38350883 0.35016323 0.35750041 0.27845259
#  0.86598408 0.20902213 0.29937825 0.00910343]]
# y: len=50, [0.01, 0.98]: 10 samples [[0.54703892 0.75503961 0.61063936 0.38285222 0.1147371  0.40288475
#  0.92977674 0.49223539 0.30417644 0.91123986]]
# colors: len=50, [0.01, 0.95]: 10 samples [[0.0916392  0.86312796 0.80095736 0.5147647  0.41605533 0.17121476
#  0.72706435 0.75327473 0.15139265 0.78954399]]
# area: len=50, [0.41, 693.81]: 10 samples [[139.03669497 317.86614774 296.60719018 115.27525241 161.83321552
#    0.41352571 271.1382415    1.46481299   7.22000224 340.36851375]]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# ## Kết thúc
